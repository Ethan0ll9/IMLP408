# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [0.05395717 1.31862657 0.99589155 1.11216205 0.50622233 0.69237743
#  2.61762063 1.30913589 1.00992821 1.5377131  2.57936531 2.43904308
#  3.51143503 1.96606576 1.1499959  3.22478184 2.67422988 1.56240395
#  2.86307615 2.71451241 3.43129212 2.67117083 3.52977505 4.47005683
#  4.59092525 4.41127483 5.31374768 3.31655721 4.21887882 3.98476835
#  4.55913462 4.692998   4.90699652 4.92679706 5.16791156 4.62498586
#  5.20592327 4.76620823 5.41152757 5.91784933 5.97969893 5.32261578
#  6.28528529 5.16950597 6.39806919 5.56029973 6.42833464 6.30713037
#  7.17485615 6.4767056 ]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.70778546 0.83159816 0.95541085 1.07922355 1.20303624 1.32684894
#  1.45066163 1.57447433 1.69828703 1.82209972 1.94591242 2.06972511
#  2.19353781 2.3173505  2.4411632  2.56497589 2.68878859 2.81260128
#  2.93641398 3.06022667 3.18403937 3.30785206 3.43166476 3.55547745
#  3.67929015 3.80310285 3.92691554 4.05072824 4.17454093 4.29835363
#  4.42216632 4.54597902 4.66979171 4.79360441 4.9174171  5.0412298
#  5.16504249 5.28885519 5.41266788 5.53648058 5.66029328 5.78410597
#  5.90791867 6.03173136 6.15554406 6.27935675 6.40316945 6.52698214
#  6.65079484 6.77460753]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.3553349806077291

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.21336441])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.7077854628572857

# %%
Y
# Out:
# array([0.70778546, 0.83159816, 0.95541085, 1.07922355, 1.20303624,
#        1.32684894, 1.45066163, 1.57447433, 1.69828703, 1.82209972,
#        1.94591242, 2.06972511, 2.19353781, 2.3173505 , 2.4411632 ,
#        2.56497589, 2.68878859, 2.81260128, 2.93641398, 3.06022667,
#        3.18403937, 3.30785206, 3.43166476, 3.55547745, 3.67929015,
#        3.80310285, 3.92691554, 4.05072824, 4.17454093, 4.29835363,
#        4.42216632, 4.54597902, 4.66979171, 4.79360441, 4.9174171 ,
#        5.0412298 , 5.16504249, 5.28885519, 5.41266788, 5.53648058,
#        5.66029328, 5.78410597, 5.90791867, 6.03173136, 6.15554406,
#        6.27935675, 6.40316945, 6.52698214, 6.65079484, 6.77460753])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.3478787])

# %%
y
# Out:
# array([0.05395717, 1.31862657, 0.99589155, 1.11216205, 0.50622233,
#        0.69237743, 2.61762063, 1.30913589, 1.00992821, 1.5377131 ,
#        2.57936531, 2.43904308, 3.51143503, 1.96606576, 1.1499959 ,
#        3.22478184, 2.67422988, 1.56240395, 2.86307615, 2.71451241,
#        3.43129212, 2.67117083, 3.52977505, 4.47005683, 4.59092525,
#        4.41127483, 5.31374768, 3.31655721, 4.21887882, 3.98476835,
#        4.55913462, 4.692998  , 4.90699652, 4.92679706, 5.16791156,
#        4.62498586, 5.20592327, 4.76620823, 5.41152757, 5.91784933,
#        5.97969893, 5.32261578, 6.28528529, 5.16950597, 6.39806919,
#        5.56029973, 6.42833464, 6.30713037, 7.17485615, 6.4767056 ])
